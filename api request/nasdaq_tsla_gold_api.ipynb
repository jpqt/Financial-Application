# %%
#PROJECT-1 GROUP-3
# MAKING ALPACA API CALL WITH REQUEST LIBRARY

# %%
#import required libraries and dependencies 

import pandas as pd
import os
from dotenv import load_dotenv
import requests
import json

# %%
load_dotenv()
# Out:
# True

# %%
nasdaq_api_key = os.getenv("nasdaq_api_key")
type(nasdaq_api_key)
# Out:
# str

# %%
#retrieve api key from env variable and store as python variable

#nasdaq_api_key = os.getenv("")
#type(nasdaq_api_key)

#define base request url for nasdaq
request_url = "https://www.nasdaq.com/market-activity"

# %%
#make API request from nasdaq site
#display response data (super long list)
response = requests.get("https://data.nasdaq.com/api/v3/datasets").json()
#print(json.dumps(response, indent=4, sort_keys=True)) (maybe not this section)

# %%
#test
#set the GOLD endpoint

lmba_gold_url ="https://data.nasdaq.com/api/v3/datasets/LBMA/GOLD.json?api_key=TTVYZB2Uoz_K6x7oKPG_"
requests.get(lmba_gold_url).json()
#print(json.dumps(response_gold, indent=2, sort_keys=True))
# Out:
# {'dataset': {'id': 11304240,
#   'dataset_code': 'GOLD',
#   'database_code': 'LBMA',
#   'name': 'Gold Price: London Fixing',
# ...

# %%
#test

#set SPY endpoint:
#spy_url = https://data.alpaca.markets/v2/
#requests.get(spy_url).json()

# %%
#spy and gold endpoint ripple
#spy_gold_url = "https://data.nasdaq.com/api/v3/datatables/ETFG/FUND.json?ticker=SPY,GLD&qopts.columns=ticker,date,shares_outstanding&api_key=TTVYZB2Uoz_K6x7oKPG_"

#requests.get(spy_gold_url).json()
